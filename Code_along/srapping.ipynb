# %%
import pandas as pd

df_list = pd.read_html("https://en.wikipedia.org/wiki/List_of_largest_Nordic_companies")

len(df_list), type(df_list)
# Out:
# (4, list)

# %%
df_rank = df_list[1]

# %%
df_country = df_list[2]

# %%
df_size = df_list[3]

# %%
df_rank.to_csv("nordic_rnaking_company.csv", index=False)
